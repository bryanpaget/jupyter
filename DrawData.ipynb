# %%
# %%capture
! pip install drawdata

# %%
import pandas as pd
from drawdata import draw_scatter

draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("drawdata.csv")
df.plot()
# Out:
# <Axes: >
